# %%
print("Hello World")
# Out:
# Hello World

# %%
import os
from pathlib import Path
from dotenv import load_dotenv

load_dotenv()
# Out:
# False

# %%
BASE_DIR = Path().resolve()
print(BASE_DIR)
# Out:
# /Users/admin/anil_reddaboina/ailearning/sementic-image-search/semantic_image_search/notebooks

# %%
images_root = BASE_DIR/"images"

print(images_root)
# Out:
# /Users/admin/anil_reddaboina/ailearning/sementic-image-search/semantic_image_search/notebooks/images

# %%
load_dotenv()
# Out:
# False
